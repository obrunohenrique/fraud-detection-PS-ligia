# %%
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#        id      Time        V1        V2        V3        V4        V5  \
# 0  265519  161919.0  1.946747 -0.752526 -1.355130 -0.661630  1.502822
# 1  180306  124477.0  2.035149 -0.048880 -3.058693  0.247945  2.943487
# 2   42665   41191.0 -0.991920  0.603193  0.711976 -0.992425 -0.825838
# 3  198724  132624.0  2.285718 -1.500239 -0.747565 -1.668119 -1.394143
# 4   82326   59359.0 -0.448747 -1.011440  0.115903 -3.454854  0.715771
#
#          V6        V7        V8  ...       V21       V22       V23       V24  \
# 0  4.024933 -1.479661  1.139880  ...  0.076197  0.297537  0.307915  0.690980
# 1  3.298697 -0.002192  0.674782  ...  0.038628  0.228197  0.035542  0.707090
# 2  1.956261 -2.212603 -5.037523  ... -2.798352  0.109526 -0.436530 -0.932803
# 3 -0.350339 -1.427984  0.010010  ... -0.139670  0.077013  0.208310 -0.538236
# 4 -0.147490  0.504347 -0.113817  ... -0.243245 -0.173298 -0.006692 -1.362383
#
#         V25       V26       V27       V28  Amount  Class
# 0 -0.350316 -0.388907  0.077641 -0.032248    7.32      0
# 1  0.512885 -0.471198  0.002520 -0.069002    2.99      0
# 2  0.826684  0.913773  0.038049  0.185340  175.10      0
# 3 -0.278032 -0.162068  0.018045 -0.063005    6.10      0
# 4 -0.292234 -0.144622 -0.032580 -0.064194   86.10      0
#
# [5 rows x 32 columns]

# %%
train_df.isnull().sum()
# Out:
# id        0
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Engenharia de features

# %%
def engenharia_de_features(df):
  df['Hour'] = (df['Time'] / 3600) % 24
  df['is_dawn'] = (df['Hour'] <= 6).astype(int)
  return df.drop(['Time'], axis=1)

# %%
train_df = engenharia_de_features(train_df)

train_df.head()
# Out:
#        id        V1        V2        V3        V4        V5        V6  \
# 0  265519  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933
# 1  180306  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697
# 2   42665 -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261
# 3  198724  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339
# 4   82326 -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490
#
#          V7        V8        V9  ...       V23       V24       V25       V26  \
# 0 -1.479661  1.139880  1.406819  ...  0.307915  0.690980 -0.350316 -0.388907
# 1 -0.002192  0.674782  0.045826  ...  0.035542  0.707090  0.512885 -0.471198
# 2 -2.212603 -5.037523  0.000772  ... -0.436530 -0.932803  0.826684  0.913773
# 3 -1.427984  0.010010 -1.118447  ...  0.208310 -0.538236 -0.278032 -0.162068
# 4  0.504347 -0.113817 -0.044782  ... -0.006692 -1.362383 -0.292234 -0.144622
#
#         V27       V28  Amount  Class       Hour  is_dawn
# 0  0.077641 -0.032248    7.32      0  20.977500        0
# 1  0.002520 -0.069002    2.99      0  10.576944        0
# 2  0.038049  0.185340  175.10      0  11.441944        0
# 3  0.018045 -0.063005    6.10      0  12.840000        0
# 4 -0.032580 -0.064194   86.10      0  16.488611        0
#
# [5 rows x 33 columns]

# %% [markdown]
# ## divisão treino e validação

# %%
# 3. Divisão treino e validacao

X = train_df.drop(columns=['Class', 'id'])
y = train_df['Class']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
print(f"Nulos no X: {X.isnull().sum().sum()}")
print(f"Nulos no y: {y.isnull().sum()}")
# Out:
# Nulos no X: 0
# Nulos no y: 0

# %% [markdown]
# ## Escalar dataset

# %%
scaler = RobustScaler()
cols_to_scale = [c for c in X_train.columns if c != 'is_dawn' and c != 'id']

# %%
X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])

X_val[cols_to_scale] = scaler.transform(X_val[cols_to_scale])

# %% [markdown]
# ## Salvando objetos

# %%
# Salvar objetos para os próximos modelos
joblib.dump(scaler, 'scaler_final.joblib')
joblib.dump((X_train, y_train, X_val, y_val), 'dados_processados_dev.joblib')
# Out:
# ['dados_processados_dev.joblib']

# %%
test_kaggle_bruto = pd.read_csv('test.csv')
test_proc = engenharia_de_features(test_kaggle_bruto)
test_proc[cols_to_scale] = scaler.transform(test_proc[cols_to_scale])

joblib.dump(test_proc, 'X_test_kaggle.joblib')
# Out:
# ['X_test_kaggle.joblib']
